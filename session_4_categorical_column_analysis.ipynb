# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
visa_df = pd.read_csv(r"C:\Users\vinay\Downloads\Visadataset (1).csv")

# %%
bank_df = pd.read_csv(r"C:\Users\vinay\Eda 2\bank.csv",sep=';')
cat1 = bank_df.select_dtypes(include = object).columns
num1 = bank_df.select_dtypes(exclude = object).columns

# %%
cat = visa_df.select_dtypes(include = object).columns
num = visa_df.select_dtypes(exclude = object).columns

# %%
keys = visa_df['continent'].value_counts().keys()
values = visa_df['continent'].value_counts().values

plt.figure(figsize = (10,4))
plt.bar(keys, values)
# Out:
# <BarContainer object of 6 artists>

# %%
plt.figure(figsize=(15,8))
plt.subplot(2,2,1)
plt.title('2-2-1')
plt.subplot(2,2,2)
plt.title('2-2-2')
plt.subplot(2,2,3)
plt.title('2-2-3')
plt.subplot(2,2,4)
plt.title('2-2-4')
# Out:
# Text(0.5, 1.0, '2-2-4')

# %%
plt.subplot(3,1,1)
plt.subplot(3,1,2)
plt.subplot(3,1,3)
# Out:
# <Axes: >

# %%
plt.subplot(1,3,1)
plt.subplot(1,3,2)
plt.subplot(1,3,3)
# Out:
# <Axes: >

# %%
keys = bank_df['job'].value_counts().keys()
values = bank_df['job'].value_counts().values

plt.figure(figsize=(15,4))
plt.suptitle('Job')
plt.subplot(1,2,1)
plt.bar(keys, values)
plt.xlabel('Name of Job')
plt.ylabel('No of employee')

plt.subplot(1,2,2)

plt.pie(x = values, labels = keys,autopct = '%0.2f%%')
plt.show()

# %%
# plt.subplot(2,2,i)
for i in range(1,5):
    plt.subplot(2,2,i)

# %%
# plt.subplot(2,2,i)
plt.figure(figsize=(18,9))
for i in range(1,10):
    plt.subplot(3,3,i)

# %%
# plt.subplot(2,2,i)
plt.figure(figsize=(18,4))
for i in range(1,10):
    plt.subplot(2,5,i)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (25,25))
for i in range(1,len(cat)):
    keys = visa_df[cat[i]].value_counts().keys()
    values = visa_df[cat[i]].value_counts().values
  
    plt.subplot(3,3,i)
    plt.bar(keys, values,
           color = plt.cm.tab10.colors)
    plt.xticks(rotation = 30)
    plt.xlabel('Continets')
    plt.ylabel('Values')
    plt.title(cat[i])

# %%
bank_df
plt.figure(figsize=(20,10))
for i in range(1,len(cat1)):
    keys=bank_df[cat1[i]].value_counts().keys()
    values = bank_df[cat1[i]].value_counts().values


    plt.subplot(3,3,i).bar(keys,values)
    plt.title(f'{cat1[i]}_bar')

    plt.suptitle('Bar-Charts')

# %%
bank_df
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
visa_df = pd.read_csv(r"C:\Users\vinay\Downloads\Visadataset (1).csv")
cat1 = visa_df.select_dtypes(include = object).columns
num1 = visa_df.select_dtypes(exclude = object).columns

# %%
cat
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
cat1
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
num1
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %% [markdown]
# **prevailling_wage**

# %% [markdown]
# - len
#
# - max
#
# - min
#
# - min
#
# - median
#
# - 25 percentile
#
# - 50 percentile
#
# - 75 perentile

# %%
wage_data = visa_df['prevailing_wage']

# %%
len(visa_df['prevailing_wage'])
# Out:
# 25480

# %%
visa_df['prevailing_wage'].min()
# Out:
# 2.1367

# %%
min(visa_df['prevailing_wage'])
# Out:
# 2.1367

# %%
np.min(visa_df['prevailing_wage'])
# Out:
# 2.1367

# %%
wage = visa_df['prevailing_wage']

# %%
max(wage)
# Out:
# 319210.27

# %%
wage.max()
# Out:
# 319210.27

# %%
wage.median()
# Out:
# 70308.20999999999

# %%
wage.mode()
# Out:
# 0        100.66
# 1        102.70
# 2        105.96
# 3        108.12
# 4        109.06
# 5        110.51
# 6        111.11
# 7        113.60
# 8        118.43
# 9        122.65
# 10       127.89
# 11       134.15
# 12       138.76
# 13      6036.67
# 14     21894.51
# 15     24258.73
# 16     58770.05
# 17     60948.15
# 18     64357.58
# 19     74645.92
# 20     82560.28
# 21     87751.88
# 22     88664.77
# 23     93356.03
# 24    126813.75
# 25    149907.39
# Name: prevailing_wage, dtype: float64

# %%
wage.max()
# Out:
# 319210.27

# %%
wage.max() - wage.min()
# Out:
# 319208.13330000004

# %%
wage.mean(), np.mean(wage) # both methods are same
# Out:
# (74455.81459209183, 74455.81459209183)

# %% [markdown]
# **quantile-percentile**

# %%
p_25 = np.percentile(wage_data,25)
p_25
# Out:
# 34015.479999999996

# %%
p_25 = np.percentile(wage_data,25)
p_25
# Out:
# 107735.51250000001

# %%
q_25 = np.quantile(wage_data, 0.25)
q_25
# Out:
# 34015.479999999996

# %%
q_50 = np.quantile(wage_data, 0.50)
q_50
# Out:
# 70308.20999999999

# %%
q_75 = np.quantile(wage_data, 0.75)
q_75
# Out:
# 107735.51250000001

# %%
visa_df['prevailing_wage']
wage_count = len(wage_data)

# %%
wage_data = visa_df['prevailing_wage']
wage_count = len(wage_data)
wage_min = round(wage_data.min(),2)
wage_mean = round(wage_data.mean(),2)
wage_median = round(wage_data.median(),2)
wage_25p = round(np.percentile(wage_data,25),2)
wage_50p = round(np.percentile(wage_data,50),2)
wage_75p = round(np.percentile(wage_data,75),2)
wage_max = round(wage_data.max(),2)
l = [wage_count, wage_min, wage_mean, wage_median, wage_25p, wage_50p, wage_75p, wage_max]
Id = ['Count', 'min', 'mean', 'median', '25p', '50p', '75', 'max']

# %%
df = pd.DataFrame(zip(Id, l),
                 )
df
# Out:
#         0          1
# 0   Count   25480.00
# 1     min       2.14
# 2    mean   74455.81
# 3  median   70308.21
# 4     25p   34015.48
# 5     50p   70308.21
# 6      75  107735.51
# 7     max  319210.27

# %%
len(visa_df)
# Out:
# 25480

# %%
print('{0:.2}'.format(1.0 / 3))
# Out:
# 0.33

# %%
print('{0:.3}'.format(1.0 / 3))
# Out:
# 0.333

# %%
print ('{0:-2%}'.format(1.0 / 3))
# Out:
# 33.333333%

# %%
print('cd'.partition('cd'))
# Out:
# ('', 'cd', '')

# %%
print('abef'.partition('cd'))
# Out:
# ('abef', '', '')

# %%
print('acdf'.partition('cd'))
# Out:
# ('a', 'cd', 'f')

# %%
print('acdf'.partition('cd'))
# Out:
# ('a', 'cd', 'f')

# %%
s = ["Geeks", "for", "Geeks"]

# using for loop with string
for i in s:
    print(i)
# Out:
# Geeks
# for
# Geeks

# %%
for i in 'geeksforgeeks':

    # break the loop as soon it sees 'e'
    # or 's'
    if i == 'e' or i == 's':
        break

print(i)
# Out:
# e

# %%
# An empty loop
for i in 'geeksforgeeks':
    pass
print(i)
# Out:
# s

# %%
# An empty loop
for i in 'geeksforgeeks':
    pass
    print(i)
# Out:
# g
# e
# e
# k
# s
# f
# o
# r
# g
# e
# e
# k
# s

# %%
x = 10
x = 'ho'
print(x)
# Out:
# ho
