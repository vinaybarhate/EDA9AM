# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
visa_df=pd.read_csv(r"C:\Users\vinay\Eda 2\Visadataset.csv")
bank_df=pd.read_csv(r"C:\Users\vinay\Eda 2\bank.csv",sep=';')

# %%
cate = bank_df.select_dtypes(include = object).columns
cate
# Out:
# Index(['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact',
#        'month', 'poutcome', 'y'],
#       dtype='object')

# %%
keys = visa_df['continent'].value_counts().keys()
values = visa_df['continent'].value_counts().values
df = pd.DataFrame(zip(keys,values),
                 columns = ['labels', 'no of aplicants'])
df.to_csv('continent_csv', index = False)
df
# Out:
#           labels  no of aplicants
# 0           Asia            16861
# 1         Europe             3732
# 2  North America             3292
# 3  South America              852
# 4         Africa              551
# 5        Oceania              192

# %%
cat = visa_df.select_dtypes(include = object).columns
numerical_col = visa_df.select_dtypes(exclude = object).columns

# %% [markdown]
# **Step 1: create a folder usingg python code**

# %%
import os 
try:
    os.makedirs('Frequency_tables')
except Exception as e:
    print(e)
# Out:
# [WinError 183] Cannot create a file when that file already exists: 'Frequency_tables'

# %%
os.makedirs('Frequency_tables', exist_ok = True)

# %%
keys = visa_df['continent'].value_counts().keys()
values = visa_df['continent'].value_counts().values
df = pd.DataFrame(zip(keys,values),
                 columns = ['labels', 'no of aplicants'])
df.to_csv('continent_csv', index = False)

path= r"C:\Users\vinay\Eda 2\Frequency_tables\continent.csv"
df.to_csv(path, index=False)

# %%
# path= r"C:\Users\vinay\Eda 2\Frequency_tables\continent1.csv"  Absolute Path
# path = r".\Frequency_tables\continent2.csv" # relative path

# %%
keys = visa_df['continent'].value_counts().keys()
values = visa_df['continent'].value_counts().values
df = pd.DataFrame(zip(keys,values),
                 columns = ['labels', 'no of aplicants'])
df.to_csv('continent_csv', index = False)



path = r".\Frequency_tables\continent2.csv" # relative path

df.to_csv(path, index=False)

# %%
cwd = os.getcwd() # EDA
folder_name = 'Frequency_tables'
new_dir = os.path.join(cwd, folder_name)
filename = 'continent.csv'
path = os.path.join(new_dir, filename)
df.to_csv(path,index=False)
print(path)
# Out:
# C:\Users\vinay\Eda 2\Frequency_tables\continent.csv

# %%
cwd
# Out:
# 'C:\\Users\\vinay\\Eda 2'

# %%
keys = visa_df['continent'].value_counts().keys()
values = visa_df['continent'].value_counts().values
df = pd.DataFrame(zip(keys,values),
                 columns = ['labels', 'no of aplicants'])

folder_name = 'frequency_table'
os.makedirs(folder_name, exist_ok = True)


cwd = os.getcwd()
new_dir = os.path.join(cwd, folder_name)
file_name = 'continent3.csv'
path = os.path.join(new_dir, file_name)

df.to_csv(path, index=False)

# %%
for i in cat[1:]:
    keys = visa_df[i].value_counts().keys()
    values = visa_df[i].value_counts().values
    df = pd.DataFrame(zip(keys,values),
                     columns = ['labels', 'no of aplicants'])
    
    folder_name = 'frequency_table'
    os.makedirs(folder_name, exist_ok = True)
    
    
    cwd = os.getcwd()
    new_dir = os.path.join(cwd, folder_name)
    file_name = f'{i}.csv'
    path = os.path.join(new_dir, file_name)
    
    df.to_csv(path, index=False)

# %%
for i in cat[1:]:
    keys = visa_df[i].value_counts().keys()
    values = visa_df[i].value_counts().values

    # for creating folder use o.makrdirs(folder_name)
    folder_name = 'bar_charts'
    os.makedirs(folder_name, exist_ok = True)
    
    # for finding pathway until eda2
    cwd = os.getcwd()
    # for adding folder_name in pathway
    new_dir = os.path.join(cwd, folder_name)
    file_name = f'{i}.jpg'
    # for adding files in the folder
    path = os.path.join(new_dir, file_name)
    
    
    plt.figure(figsize=(10,4))
    plt.bar(keys,values)
    plt.xlabel('labels')
    plt.ylabel('count')
    plt.title(f'{i} barchart')
    plt.savefig(path)
    plt.show()

# %%
for i in cat[1:]:
    keys = visa_df[i].value_counts().keys()
    values = visa_df[i].value_counts().values
    df = pd.DataFrame(zip(keys,values),
                     columns = ['labels', 'no of aplicants'])
    
    folder_name = 'pie_charts'
    os.makedirs(folder_name, exist_ok = True)
    
    
    cwd = os.getcwd()
    new_dir = os.path.join(cwd, folder_name)
    file_name = f'{i}.jpg'
    path = os.path.join(new_dir, file_name)
    
    
    plt.figure(figsize=(12,4))
    plt.pie(x=values,labels=keys,
            explode = ([0.1 for i in range(len(keys))]),
            autopct='%0.2f%%')
    plt.title(f'{i}_piechart')
    plt.savefig(path)
    
    plt.show()

# %% [markdown]
# # Bar Chart Automate

# %%
for i in cat[1:]:
    keys = visa_df[i].value_counts().keys()
    values = visa_df[i].value_counts().values
   
    folder_name = ('frequency_table')
    
    os.makedirs(folder_name, exist_ok = True)
    
    cwd = os.getcwd()
    new_dir = os.path.join(cwd, folder_name)
    file_name = f'{i}.csv'
    path = os.path.join(new_dir, file_name)
    
    df.to_csv(path, index=False)

# %%
    
    plt.figure(figsize=(10,4))
    colors = ['black', 'blue']
    col = ['red', 'green']
    plt.bar(keys,values, edgecolor = colors,
           color = col)
    plt.xlabel('labels')
    plt.ylabel('count')
    plt.title('bar barchart')
    plt.savefig(path)
    plt.show()

# %%
for i in cat[1:]:
    keys = visa_df[i].value_counts().keys()
    values = visa_df[i].value_counts().values

    folder_name = ('bar_charts_1')
    os.makedirs(folder_name, exist_ok = True)

    cwd = os.getcwd()
    new_dir = os.path.join(cwd, folder_name)
    file_name = (f'{i}.jpg')
    path = os.path.join(new_dir, file_name)
    
    plt.figure(figsize=(10,4))
    plt.bar(keys, values)
    plt.xlabel('Categories')
    plt.ylabel('values')
    plt.title(f'{i}')
    plt.savefig(path)
    plt.show()
